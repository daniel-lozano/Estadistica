# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
a=loadtxt(open("datos.dat","r"))

# %% [markdown]
# ## 100000 puntos

# %%
hist(a,100)
print len(a)
title(str(len(a)-1))
# Out:
# 100001

# %% [markdown]
# ## 1000000 puntos

# %%
hist(a,100)
print len(a)
title(str(len(a)-1))
# Out:
# 1000001

# %% [markdown]
# ## 10000000 puntos

# %%
hist(a,100)
print len(a)
title(str(len(a)-1))
# Out:
# 10000001
