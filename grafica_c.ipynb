# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
a=loadtxt(open("datos.dat","r"))

# %%
hist(a,1000)
print len(a)
# Out:
# 100001

# %%
hist(a,100)
print len(a)
# Out:
# 10001

# %%
hist(a,100)
print len(a)
# Out:
# 1001

# %%
hist(a,10000,color="b")
print len(a)
title("numero de puntos "+str(len(a)-1))
savefig("1000000puntos.png")
# Out:
# 1000001
